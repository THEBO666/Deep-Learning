# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter("logs") # 创建一个logs文件夹，writer写的文件都在该文件夹下
#writer.add_image()
for i in range(100):
    writer.add_scalar("y=x",3*i,i)
writer.close()

# %% [markdown]
# tensorboard --logdir=dir --port=port

# %%
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
img_path1 = "Data/train/ants_image/0013035.jpg"
img_path2 = "Data/train/ants_image/5650366_e22b7e1065.jpg"
img_array1 = np.array(Image.open(img_path1))
img_array1.shape
img_array2 = np.array(Image.open(img_path2))
writer = SummaryWriter("logs")

writer.add_image("test",img_array1,1,dataformats='HWC')
writer.add_image("test",img_array2,2,dataformats='HWC')
